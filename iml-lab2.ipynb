# %%
#############################################################################################
#                                  Name:Bhushan Joshi                                       #
#                                  Enrollment:2162270307050                                 #
#                                  Div:G                                                    #
#                                  Government Polytechnic Porbandar                         #
#############################################################################################

#Practical 2:Write a NumPy program to implement following operation

# %%
#2.1 to convert a list of numeric values into a one-dimensional NumPy array
import numpy as np
num =[12,14,16,18,20]
onr=np.array(num)
print(onr)

# %%
#2.2  to create a 3x3 matrix with values ranging from 2 to 10
import numpy as np
mtrx=np.arange(2,11).reshape(3,3)
print(mtrx)

# %%
#2.3 to append values at the end of an array
import numpy as np
arr1=np.array([1,2,3])
arr2=np.array([4,5,6])
arr3=np.append(arr1,arr2)
print(arr3)

# %%
#2.4 to create another shape from an array without changing its data(3*2to 2*3)
import numpy as np
arr1= np.array([[1, 2],[3, 4],[5, 6]])
print(arr1)
arr2=arr1.reshape(2,3)
print(arr2)

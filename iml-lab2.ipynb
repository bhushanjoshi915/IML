# %%
#############################################################################################
#                                  Name:Bhushan Joshi                                       #
#                                  Enrollment:2162270307050                                 #
#                                  Div:G                                                    #
#                                  Government Polytechnic Porbandar                         #
#############################################################################################
